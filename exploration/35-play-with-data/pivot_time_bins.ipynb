# %% [markdown]
# ## Reading basic statistics from the Database
#
# imports and connecting to the database first

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import  psycopg2, psycopg2.extras

# %%
white = "postgres://akpurvjbqbishc:RCTDHwXUSiuKpO57Wok0V8VhZh@ec2-54-163-239-102.compute-1.amazonaws.com:5432/dfdnjlanlrg3fs"
gray = "postgres://uuzpohilphigiu:YbWYD5SOUSurzNerXSffDAN3_5@ec2-54-163-228-58.compute-1.amazonaws.com:5432/df43cbhq0k77kr"

db = psycopg2.connect(white)
db.autocommit = True
db_cursor = db.cursor(cursor_factory=psycopg2.extras.DictCursor)

# %% [markdown]
# ## Example Code
#
# reading pandas datafram from the database

# %%
group_df = pd.read_sql("SELECT id_group,name,join_mode from groups", db, index_col='id_group')
group_df.head()
# Out:
#                                                        name join_mode
# id_group
# 213657                    The New York Figure Drawing Group      open
# 297702                                 NEW YORK MUSEUM CLUB      open
# 483619    NYC Contemporary Art - NYC Art Events Artists ...  approval
# 525703                                 Asian Artists Meetup  approval
# 682776               New York Art Travelers/Art Adventurers      open

# %%
rsvp_by_year = pd.read_sql("SELECT * from event_rsvps_by_year", db).pivot(index='id_group', columns='time_bin', values='sum')
rsvp_by_year.rename(columns=lambda x: "rsvps-year-%04d" % x.year, inplace=True)
rsvp_by_year.head()
# Out:
# time_bin  rsvps-year-2003  rsvps-year-2004  rsvps-year-2005  rsvps-year-2006  \
# id_group
# 10001272              NaN              NaN              NaN              NaN
# 10007032              NaN              NaN              NaN              NaN
# 10007272              NaN              NaN              NaN              NaN
# 10008572              NaN              NaN              NaN              NaN
# 10010282              NaN              NaN              NaN              NaN
#
# time_bin  rsvps-year-2007  rsvps-year-2008  rsvps-year-2009  rsvps-year-2010  \
# id_group
# 10001272              NaN              NaN              NaN              NaN
# 10007032              NaN              NaN              NaN              NaN
# 10007272              NaN              NaN              NaN              NaN
# 10008572              NaN              NaN              NaN              NaN
# 10010282              NaN              NaN              NaN              NaN
#
# ...

# %%
rsvp_by_month = pd.read_sql("SELECT * from event_rsvps_by_month", db).pivot(index='id_group', columns='time_bin', values='sum')
rsvp_by_month.rename(columns=lambda x: "rsvps-month-%04d-%02d" % (x.year, x.month), inplace=True)
rsvp_by_month.head()
# Out:
# time_bin  rsvps-month-2003-03  rsvps-month-2004-09  rsvps-month-2004-10  \
# id_group
# 10001272                  NaN                  NaN                  NaN
# 10007032                  NaN                  NaN                  NaN
# 10007272                  NaN                  NaN                  NaN
# 10008572                  NaN                  NaN                  NaN
# 10010282                  NaN                  NaN                  NaN
#
# time_bin  rsvps-month-2004-11  rsvps-month-2004-12  rsvps-month-2005-01  \
# id_group
# 10001272                  NaN                  NaN                  NaN
# 10007032                  NaN                  NaN                  NaN
# 10007272                  NaN                  NaN                  NaN
# 10008572                  NaN                  NaN                  NaN
# 10010282                  NaN                  NaN                  NaN
#
# time_bin  rsvps-month-2005-02  rsvps-month-2005-03  rsvps-month-2005-04  \
# ...

# %%
df2 = group_df.merge(rsvp_by_year, left_index=True, right_index=True)
df2 = df2.merge(rsvp_by_month, left_index=True, right_index=True)
df2.head()
# Out:
#                                                        name join_mode  \
# id_group
# 10001272                                               None  approval
# 10007032  Real, Connected, Phenomenal Women Friends in t...      open
# 10007272           Startup  Pitch Practice Fairfield County      open
# 10008572                  Unitarian Church of Staten Island      open
# 10010282                         NYC Technical Trader Talks      open
#
#           rsvps-year-2003  rsvps-year-2004  rsvps-year-2005  rsvps-year-2006  \
# id_group
# 10001272              NaN              NaN              NaN              NaN
# 10007032              NaN              NaN              NaN              NaN
# 10007272              NaN              NaN              NaN              NaN
# 10008572              NaN              NaN              NaN              NaN
# 10010282              NaN              NaN              NaN              NaN
#
# ...
